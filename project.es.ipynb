# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
#V1 : Volvemos a revisar juntos los ejercicios que hicimos semana pasada en V1 para mejorar respuestas.
#Grupo = Carla, Beatriz, Vicente 

#Usamos idxmax, igual que V1, pero mejoro print, que era muy largo:

max_price_row = ds.loc[ds['price'].idxmax()]
print('La casa con dirreción en la calle', max_price_row['address'], 'en', max_price_row['level1'], 'es la más cara y su precio es de', max_price_row['price'], 'USD.')
# Out:
# La casa con dirreción en la calle El Escorial en Madrid es la más cara y su precio es de 8500000 USD.

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
#Quito codigos inutíles :

min_price_row_not_null = ds.loc[ds['price'].replace(0, float('inf')).idxmin()]
print('La casa con dirreción calle',min_price_row_not_null['address'],'es la más barata y su precio es de',min_price_row_not_null['price'],'USD.')
# Out:
# La casa con dirreción calle Berlin, Coslada es la más barata y su precio es de 600 USD.

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
import numpy as np
#simplifico y quito lineas inutiles:

max_surface_value = np.nanmax(ds['surface'])
max_surface_row = ds[ds['surface'] == max_surface_value].iloc[0]

print('La casa más grande está ubicada en', max_surface_row['address'], 'y su superficie es de', round(max_surface_row['surface']), 'metros cuadrados.')

min_surface_value = np.nanmin(ds['surface'])
min_surface_row = ds[ds['surface'] == min_surface_value].iloc[0]

print('La casa más pequeña está ubicada en', min_surface_row['address'], 'y su superficie es de', round(min_surface_row['surface']), 'metros cuadrados.')
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000 metros cuadrados.
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15 metros cuadrados.

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

#Simplifico y uso join() como los compañeros: 
# + quise buscar para que salga en orden alfabético. Solo con sorted, me salía Madrid primero, hay que borrar espacios al inicio, añado .strip:

num_city = len(ds['level5'].unique())
list_city = ', '.join(sorted([city.strip() for city in ds['level5'].unique()])) 
print('Hay', num_city, 'poblaciones en el Dataset, aquí está la lista:',list_city)
# Out:
# Hay 168 poblaciones en el Dataset, aquí está la lista: Ajalvir, Alcalá de Henares, Alcobendas, Alcorcón, Aldea del Fresno, Algete, Alpedrete, Ambite, Anchuelo, Aranjuez, Arganda del Rey, Arroyomolinos (Madrid), Batres, Becerril de la Sierra, Belmonte de Tajo, Boadilla del Monte, Braojos, Brea de Tajo, Brunete, Buitrago del Lozoya, Bustarviejo, Cabanillas de la Sierra, Cadalso de los Vidrios, Camarma de Esteruelas, Campo Real, Canencia, Carabaña, Casarrubuelos, Cenicientos, Cercedilla, Chapinería, Chinchón, Ciempozuelos, Cobeña, Collado Mediano, Collado Villalba, Colmenar Viejo, Colmenar de Oreja, Colmenar del Arroyo, Colmenarejo, Corpa, Coslada, Cubas de la Sagra, Daganzo de Arriba, El Atazar, El Berrueco, El Boalo - Cerceda – Mataelpino, El Escorial, El Molar (Madrid), El Vellón, El Álamo, Estremera, Fresnedillas de la Oliva, Fresno de Torote, Fresno de Torote - Serracines, Fuenlabrada, Fuente El Saz de Jarama, Fuentidueña de Tajo, Galapagar, Garganta de los Montes, Gargantilla del 
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
#Se compruebe si hay NAs en el Dataset:

#Nota : habia usado isnan en la V1, pero no así, ahora se añade .any para comprobar: 
#el primero se usa para saber si al menos un valor es True, y se usa un segundo para que se aplique a todas las columnas

print('Si hay NAs en el Dataset' if ds.isna().any().any() else 'No hay NAs en el Dataset')


#Uso codigo parecido a mi V1, con el np.where para tener indices + modifico para que se ponga de frente en el print añadiendo .join:

print("\n".join([f"True, Fila: {row}, Columna: {ds.columns[col]}" for row, col in zip(*np.where(ds.isna()))]))
# Out:
# Si hay NAs en el Dataset
# True, Fila: 0, Columna: level6
# True, Fila: 0, Columna: level8
# True, Fila: 0, Columna: zipCode
# True, Fila: 0, Columna: customZone
# True, Fila: 1, Columna: surface
# True, Fila: 1, Columna: level6
# True, Fila: 1, Columna: level8
# True, Fila: 1, Columna: zipCode
# True, Fila: 1, Columna: customZone
# True, Fila: 2, Columna: level6
# True, Fila: 2, Columna: level8
# True, Fila: 2, Columna: zipCode
# True, Fila: 2, Columna: customZone
# True, Fila: 3, Columna: level6
# True, Fila: 3, Columna: level8
# True, Fila: 3, Columna: zipCode
# True, Fila: 3, Columna: customZone
# True, Fila: 4, Columna: level6
# True, Fila: 4, Columna: level8
# True, Fila: 4, Columna: zipCode
# True, Fila: 4, Columna: customZone
# True, Fila: 5, Columna: level6
# True, Fila: 5, Columna: level8
# True, Fila: 5, Columna: zipCode
# True, Fila: 5, Columna: customZone
# True, Fila: 6, Columna: level6
# True, Fila: 6, Columna: level8
# True, Fila: 6, Columna: zipCode
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
#Mismo metodo que V1 pero quito lineas inutiles : 

print(ds.shape, 'VS', ds.dropna().shape)
# Out:
# (15335, 37) VS (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
#Igual, quito lineas inutiles de la V1 y pongo todo en una sola variable avg, en lugar de 2 etapas, lo hago en 1, y print:
avg_price_arroyo = ds[ds['level5'] == 'Arroyomolinos (Madrid)']['price'].mean()
print('El precio medio en Arroyomolinos es de', round(avg_price_arroyo, 2), 'euros.')
# Out:
# El precio medio en Arroyomolinos es de 294541.6 euros.

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt
Arroyomolinos_rows = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

plt.figure(figsize = (15, 5))

#Para ajustar mejor, cambiamos bins x la raíz cuadrada del num de lineas :
plt.hist(Arroyomolinos_rows['price'], bins=int(np.sqrt(15335)), alpha=0.5, color='skyblue', edgecolor='black')


plt.title("House prices in Arroyomolinos (Madrid)")
plt.xlabel("Price")
plt.ylabel("Count_houses_with_this_price")
plt.show()

# %% [markdown]
# Gracias a ese histogramo nos damos cuenta muy rapidamente de la repartición de los precios de las casas en Arroyomolinos.
# Observamos que la mayoría de las casas cuestan entre 200k y 400k. Eso es muy coherente con la media que encontremos en el ejercicio anterior, ya que el resultado fue cerca de 300k. Además vemos que hay muchas casas que cuestan alrededor de ese precio (12 están a 290k, es la frequencia máxima).
# Hay solo 2 casas que cuestan menos de 100k, son las más baratas y las 3 más caras cuestan más de 500k.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

#Cambios vs V1 --> Usamos .apply directamente, y simplifico mi print :

ds['pps'] = ds.apply(lambda x: x['price'] / x['surface'] if x['surface'] >0 else None, axis =1)

media_valde = ds[ds['level5']== 'Valdemorillo']['pps'].mean()
media_gala = ds[ds['level5']== 'Galapagar']['pps'].mean()

print( 'Promedio de precio x m2 en Valdemorillo:', round(media_valde, 2),'€\n Promedio de precio x m2 en Galapagar:',round(media_gala,2),
      '€\n En Galapager los precios x m2 son más caros que en Valdemorillo, hay una diferencia de', round(media_gala - media_valde,2), '€.')
# Out:
# Promedio de precio x m2 en Valdemorillo: 1317.95 €
#  Promedio de precio x m2 en Galapagar: 1606.32 €
#  En Galapager los precios x m2 son más caros que en Valdemorillo, hay una diferencia de 288.37 €.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: 

#Versus V1 --> Quite mi filtro de <500 que habia hecho para tener más enfoque en la vista, y agrego setting con limites, para crear ese zoom

plt.figure(figsize = (10, 5))

plt.scatter(ds['surface'], ds['price'], alpha=0.7, color='red')

plt.title("Surface vs Price")
plt.xlabel('Surface')
plt.ylabel('Price')

plt.xlim(0,400)
plt.ylim(0,1000000)
plt.show()

# %% [markdown]
# La mayoría de los precios están entre 0,1 y 0,4 (sobre una escala de 1), de todas las superficies. De hecho notamos que muchas propiedades de 200 m2 y más pueden tener mismo rango de precio que las casa de mesno de 100m2. Pero si, las casa que tienen precio muy elevado, tienen en general una superficie de más de 100m2.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
#Lo que he hecho en el V1, quitando lineas inútiles : 
print('Número de agencias en el Dataset :', ds["realEstate_name"].nunique())

#Veo con compañeros que se puede usar también el dropduplicate, intento, hay que quitar la fila del título : 
print('Número de agencias en el Dataset:', ds["realEstate_name"].drop_duplicates().shape[0] - 1)
# Out:
# Número de agencias en el Dataset : 1821
# Número de agencias en el Dataset: 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

#Codigo anterior, de V1 (quito los print) :
num_cities = ds['level5'].value_counts()
biggest_result = num_cities.idxmax()
num_houses = num_cities.max()


#NUEVA FORMA :

#De frente hago una linea para la población que tiene mayor cantidad de casa, no lo hago en 2 etapas :
bigest_city = ds['level5'].value_counts().idxmax()
#Entonces uso ahi value.counts y ya no .max()
print('La población que contiene la mayor cantidad de casas es', bigest_city, '.\n Tiene en efecto :', ds['level5'].value_counts()[bigest_city], 'casas.')
# Out:
# La población que contiene la mayor cantidad de casas es  Madrid Capital .
#  Tiene en efecto : 6643 casas.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
#En V1, lo hice en 2 etapas, ahora en 1 línea :
subc_cintsur = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
print(subc_cintsur)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
#Igual que V1 pero añado xlabel y ylabel: 
avg_prices_cintsur = subc_cintsur.groupby('level5')['price'].mean()
labels = avg_prices_cintsur.index.tolist()
values = avg_prices_cintsur.values.tolist()

plt.figure(figsize = (10, 5))

plt.bar(labels, values)


plt.xlabel("City")
plt.ylabel("Average price")
plt.title("Average prices in the south Madrid south belt")
plt.show()

# %% [markdown]
# La zona más cara del cinturón sur de Madrid es Getafe, con propiedades a más de 260k €, en promedio.
# Viene despúes las zonas de Alcorcón y Leganés, las casas están en promerdio entre 210 y 230k €. Y si buscamos una zona con oportunidades más economicas, las encontraremos en Fuenlabrada, ahí el precio promedio está debajo de los 200k€, está alrededor de 180k€.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
#Se usa groupby, un V1 no lo habia presentado así, solo habia hecho print de las columnas una detras la otra

medias = subc_cintsur.groupby('level5')[['price', 'rooms', 'surface', 'bathrooms']].mean().round(2)
variances = subc_cintsur.groupby('level5')[['price', 'rooms', 'surface', 'bathrooms']].var().round(2)

print('Medias tab\n', medias,'\n')
print('Variances tab\n', variances)
# Out:
# Medias tab
#                   price  rooms  surface  bathrooms
# level5
# Alcorcón     230071.05   2.91   105.91       1.62
# Fuenlabrada  177198.02   3.03   103.62       1.45
# Getafe       265040.50   3.15   126.90       1.87
# Leganés      208682.01   2.91   105.85       1.52
#
# Variances tab
#                      price  rooms  surface  bathrooms
# level5
# Alcorcón     1.594783e+10   0.93  4244.32       0.59
# Fuenlabrada  4.701021e+09   0.36  2264.64       0.35
# Getafe       2.098267e+10   0.77  5828.11       0.66
# Leganés      1.191394e+10   0.82  3987.48       0.55

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
#Primera linea igual a mi V1 :
expensive = subc_cintsur.groupby('level5')['price'].idxmax()

#Pero veo con compañeros que se puede simplificar con loc(), y se imprimira en forma de tabla (habia hecho un for):

most_exp_cintsur = subc_cintsur.loc[expensive, ['level5', 'address', 'price' ]]
most_exp_cintsur
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO

plt.figure(figsize = (14, 5))

city_colors = {
    "Fuenlabrada": 'red',
    "Leganés": 'blue',
    "Getafe": 'green',
    "Alcorcón": 'orange'
}

for city in ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]:
    city_data = subc_cintsur[subc_cintsur['level5'] == city]
    price = city_data ['price']
    norm_price = (price - price.min()) / (price.max() - price.min())
    plt.hist(price, bins=20, alpha=0.5, edgecolor=city_colors[city], label=city, linewidth=1.5, facecolor='none')

plt.legend()
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price distribution in Madrid south belt")
plt.show()

# %%
#Eso era mi V1, todo en el mismo gráfico, quiero ahora intentar hacer como en clase, 4 subplots: 

fig, ax = plt.subplots(2, 2, figsize=(14,10))

# Subplot Fuenlabrada
ax[0, 0].hist(subc_cintsur[subc_cintsur['level5'] == 'Fuenlabrada']['price'], bins=20)
ax[0, 0].set_title('Fuenlabrada')
ax[0, 0].set_xlabel('Price')
ax[0, 0].set_ylabel('Frequency')

# Subplot Leganés 
ax[0, 1].hist(subc_cintsur[subc_cintsur['level5'] == 'Leganés']['price'], bins=20)
ax[0, 1].set_title('Leganés')
ax[0, 1].set_xlabel('Price')
ax[0, 1].set_ylabel('Frequency')

# Subplot Getafe 
ax[1, 0].hist(subc_cintsur[subc_cintsur['level5'] == 'Getafe']['price'], bins=20)
ax[1, 0].set_title('Getafe')
ax[1, 0].set_xlabel('Price')
ax[1, 0].set_ylabel('Frequency')

# Subplot Alcorcón 
ax[1, 1].hist(subc_cintsur[subc_cintsur['level5'] == 'Alcorcón']['price'], bins=20)
ax[1, 1].set_title('Alcorcón')
ax[1, 1].set_xlabel('Price')
ax[1, 1].set_ylabel('Frequency')


plt.tight_layout()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
#Igual, simplifico mi V1 y pongo avg de cada ciudad en una sola linea, no en 2 etapas. 

average_pps_getafe = (ds[ds["level5"] == "Getafe"] ["pps"]).mean()
average_pps_alcorcon = (ds[ds['level5'] == 'Alcorcón'] ['pps']).mean()

#Y hago un solo print: 

print(f'Precio medio del metro cuadrado en Getafe: {average_pps_getafe:.2f}\n',f'Precio medio del metro cuadrado en Alcorcon: {average_pps_alcorcon:.2f}', 
      '\n Gracias a esa información, vemos que el precio por metros cuadrados está más altos en Alcorcón que en Getafe.', 
      '\n Nos puede surprender ya que anteriomente llegemos a la conclusión que Getafe era la zona más cara. \n Puede significar entonces, que en Getafe las propiedades disponibles son más grandes y entonces el preciototal son más altos. Pero vale más la pena si lo raportamos al precio x m2.')
# Out:
# Precio medio del metro cuadrado en Getafe: 2066.31
#  Precio medio del metro cuadrado en Alcorcon: 2239.30
#  Gracias a esa información, vemos que el precio por metros cuadrados está más altos en Alcorcón que en Getafe.
#  Nos puede surprender ya que anteriomente llegemos a la conclusión que Getafe era la zona más cara.
#  Puede significar entonces, que en Getafe las propiedades disponibles son más grandes y entonces el preciototal son más altos. Pero vale más la pena si lo raportamos al precio x m2.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

plt.figure(figsize = (10, 5))

for city in cinturon_sur:
    city_data = subconjunto_cinturonsur[subconjunto_cinturonsur['level5'] == city]
    plt.scatter(city_data['surface'], city_data['pps'], alpha=0.6, label=city)

x = cinturon_sur['surface']
y = cinturon_sur['pps']
plt.legend()
plt.xlabel("Surface (m²)")
plt.ylabel("Price per m²")
plt.title("Price distribution per m² in the southern belt of Madrid")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 7
#       5 for city in subc_cintsur:
#       6     city_data = [subc_cintsur['level5'] == city]
# ----> 7     plt.scatter(city_data['surface'], city_data['pps'], alpha=0.6, label=city)
#      10 plt.legend()
#      11 plt.xlabel("Surface (m²)")
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
